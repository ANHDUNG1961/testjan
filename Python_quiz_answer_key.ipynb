# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/players (1).csv")

# %%
df
# Out:
#      playerid     fname      lname        position height  weight    birthday  \
# 0     1630173  Precious    Achiuwa         Forward    6-8     225  1999-09-19
# 1      203500    Steven      Adams          Center   6-11     265  1993-07-20
# 2     1628389       Bam    Adebayo  Center-Forward    6-9     255  1997-07-18
# 3     1630534     Ochai     Agbaji           Guard    6-5     215  2000-04-20
# 4     1630583     Santi     Aldama  Forward-Center    7-0     215  2001-01-10
# ..        ...       ...        ...             ...    ...     ...         ...
# 543    201152  Thaddeus      Young         Forward    6-8     235  1988-06-21
# 544   1629027      Trae      Young           Guard    6-1     164  1998-09-19
# 545   1630209      Omer  Yurtseven          Center   6-11     275  1998-06-19
# 546    203469      Cody     Zeller  Forward-Center   6-11     240  1992-10-05
# 547   1627826     Ivica      Zubac          Center    7-0     240  1997-03-18
#
# ...

# %%
plt.scatter(df['height'], df['weight'])






# Customize the plot
plt.xlabel('height')
plt.ylabel('weight')
plt.title('Scatter Plot height vs. weight')


# Show the plot
plt.show()

# %%
type(df['height'][0])
# Out:
# str

# %%
df['feet'] = df['height'].apply(lambda x: int(x[0]))

# %%
df['inches'] = df['height'].apply(lambda x: int(x[2:]))

# %%
df.head(5)
# Out:
#    playerid     fname    lname        position height  weight    birthday  \
# 0   1630173  Precious  Achiuwa         Forward    6-8     225  1999-09-19
# 1    203500    Steven    Adams          Center   6-11     265  1993-07-20
# 2   1628389       Bam  Adebayo  Center-Forward    6-9     255  1997-07-18
# 3   1630534     Ochai   Agbaji           Guard    6-5     215  2000-04-20
# 4   1630583     Santi   Aldama  Forward-Center    7-0     215  2001-01-10
#
#        country           school  draft_year  draft_round  draft_number  feet  \
# 0      Nigeria          Memphis        2020          1.0          20.0     6
# 1  New Zealand       Pittsburgh        2013          1.0          12.0     6
# 2          USA         Kentucky        2017          1.0          14.0     6
# 3          USA           Kansas        2022          1.0          14.0     6
# 4        Spain  Loyola-Maryland        2021          1.0          30.0     7
#
#    inches
# 0       8
# 1      11
# 2       9
# 3       5
# ...

# %%
df["height in inches"] = df['feet']*12 + df['inches']

# %%
plt.scatter(df['height in inches'], df['weight'])






# Customize the plot
plt.xlabel('height')
plt.ylabel('weight')
plt.title('Scatter Plot height vs. weight')


# Show the plot
plt.show()
